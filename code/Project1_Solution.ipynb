# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** ACT and SAT had always been competing for participation. SAT has changed its syllabus in 2016.
# Did it increase participation rate?
# With the increased emphasis on Math, did students strong in Math made use of this change to get better grades in SAT?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **Overview:**
#
#
# There was a change in format for SAT in 2016. Math is now taking a bigger weightage.
# Math results influence SAT score much more than ACT (it takes up 50% weightage).
#
# ***Sources:***
#
# https://blog.prepscholar.com/act-vs-sat
#
# https://www.usnews.com/news/articles/2014/03/10/behind-the-sat-the-good-and-bad-of-the-2016-redesign
#
# https://edition.cnn.com/2014/03/05/living/sat-test-changes-schools/index.html![image.png](attachment:image.png)

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Chosen Dataset:**
#
# act_2017.csv, act_2018.csv, act_2019.csv: ACT Scores by State across in 2017, 2018, 2019
#
# sat_2017.csv, sat_2018.csv, sat_2019.csv: SAT Scores by State across in 2017, 2018, 2019

# %% [markdown]
# ### Outside Research

# %% [markdown]
# **Problem Statement:**
#
# Was this decision beneficial for College Board in its competition against ACT Inc. in its fight for market share?
#
#      - Did this decision cause any change in SAT participation rate?
#
#      - Did this decision encourage students strong in Mathematics to sit for SAT?
#
#      - Did these students switch over to SAT and abandon ACT? Or did they take both tests?

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean(num_array):
    return sum(num_array)/len(num_array)

# %%
test = [1,2,3,4,5]

# %%
mean(test)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def std_dev(num_array):
    mean = sum(num_array)/len(num_array)
    return (sum((x-mean)**2 for x in num_array)/len(num_array))**0.5

# %%
test = [1,2,3,4,5]

# %%
std_dev(test)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percent_to_float(string):
    return (float(string.replace('%',''))/100)

# %%
percent_to_float('12.34%')
# Out:
# 0.1234

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import os
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from functools import reduce
from IPython.display import display_html

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
#Read the csv into data frames
os.chdir("C:/Users/annitan/Desktop/GA/DSIF-SG-7 - Copy/Project_1/data")
act2017 = pd.read_csv('act_2017.csv')
act2018 = pd.read_csv('act_2018.csv')
act2019 = pd.read_csv('act_2019.csv')
sat2017 = pd.read_csv('sat_2017.csv')
sat2018 = pd.read_csv('sat_2018.csv')
sat2019 = pd.read_csv('sat_2019.csv')

# %% [markdown]
# #### 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
#Act Scores - 2017 (by State)
act2017.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#Act Scores - 2018 (by State)
act2018.head(5)
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
#Act Scores - 2019 (by State)
act2019.head(5)
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
#SAT Scores - 2017 (by State)
sat2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
#SAT Scores - 2018 (by State)
sat2018.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
#SAT Scores - 2019 (by State)
sat2019.head(5)
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %% [markdown]
# ### 2. Check for missing values.

# %%
#missing values for Act
print(f'Missing values for act2017:\n{act2017.isnull().sum()}\n')
print(f'Missing values for act2018:\n{act2018.isnull().sum()}\n')
print(f'Missing values for act2019:\n{act2019.isnull().sum()}\n')
# Out:
# Missing values for act2017:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64
#
# Missing values for act2018:
# State            0
# Participation    0
# Composite        0
# dtype: int64
#
# Missing values for act2019:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
#missing values for SAT
print(f'Missing values for sat2017:\n{sat2017.isnull().sum()}\n')
print(f'Missing values for sat2018:\n{sat2018.isnull().sum()}\n')
print(f'Missing values for sat2019:\n{sat2019.isnull().sum()}\n')
# Out:
# Missing values for sat2017:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# Missing values for sat2018:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64
#
# Missing values for sat2019:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %% [markdown]
# ### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# ### 4. Fix any errors you identified in steps 2-3.
# ### 5. Display the data types of each feature.
# ### 6. Fix any incorrect data types found in step 5.

# %%
#Summary/Overview of Act 2017 Data
act2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
#Summary table does not include Composite and Participation. 
#Check the data types to understand why
act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
#to first remove all % etc
act2017['Participation'] = act2017['Participation'].replace({'%':''}, regex=True)

#To change data type of composite and participation to float
act2017['Participation'] =pd.to_numeric(act2017["Participation"], errors = 'coerce')
#act2017['Composite'] =pd.to_numeric(act2017["Composite"], downcast='float', errors = 'coerce')
act2017['Composite'] =pd.to_numeric(act2017["Composite"], errors = 'coerce')

# %%
#Check the data types again
act2017.dtypes
# Out:
# State             object
# Participation      int64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
act2017.describe()
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      52.000000  52.000000  52.000000  52.000000  52.000000  51.000000
# mean       65.153846  20.919231  21.173077  22.001923  21.040385  21.535294
# std        31.832518   2.332132   1.963602   2.048672   3.151113   2.013338
# min         8.000000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%        31.000000  19.000000  19.400000  20.475000  19.900000  19.800000
# 50%        68.000000  20.550000  20.900000  21.700000  21.150000  21.400000
# 75%       100.000000  23.300000  23.100000  24.125000  22.525000  23.600000
# max       100.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %%
#Repeat the same steps for the rest of dataframe
act2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act2018['Participation'] = act2018['Participation'].replace({'%':''}, regex=True)
act2018['Participation'] =pd.to_numeric(act2018["Participation"], errors = 'coerce')

# %%
act2018.dtypes
# Out:
# State             object
# Participation      int64
# Composite        float64
# dtype: object

# %%
act2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act2019['Participation'] = act2019['Participation'].replace({'%':''}, regex=True)
act2019['Participation'] =pd.to_numeric(act2018["Participation"], errors = 'coerce')
act2019.dtypes
# Out:
# State             object
# Participation      int64
# Composite        float64
# dtype: object

# %%
#Summary/Overview of Act 2018 Data
act2018.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean       60.673077  21.544231
# std        34.545634   2.119417
# min         7.000000  17.700000
# 25%        27.000000  19.975000
# 50%        65.500000  21.300000
# 75%       100.000000  23.725000
# max       100.000000  25.600000

# %%
#Summary/Overview of Act 2019 Data
act2019.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean       60.673077  21.450000
# std        34.545634   2.175487
# min         7.000000  17.900000
# 25%        27.000000  19.800000
# 50%        65.500000  20.950000
# 75%       100.000000  23.650000
# max       100.000000  25.500000

# %%
sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
#Remove %
sat2017['Participation'] = sat2017['Participation'].replace({'%':''}, regex=True)
sat2017['Participation'] =pd.to_numeric(sat2017["Participation"], errors = 'coerce')

# %%
sat2018['Participation'] = sat2018['Participation'].replace({'%':''}, regex=True)
sat2018['Participation'] =pd.to_numeric(sat2018["Participation"], errors = 'coerce')

# %%
sat2019['Participation Rate'] = sat2019['Participation Rate'].replace({'%':''}, regex=True)
sat2019['Participation Rate'] =pd.to_numeric(sat2019["Participation Rate"], errors = 'coerce')

# %%
#Summary/Overview of Sat 2017 Data
sat2017.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean       39.803922                          569.117647  547.627451
# std        35.276632                           45.666901   84.909119
# min         2.000000                          482.000000   52.000000
# 25%         4.000000                          533.500000  522.000000
# 50%        38.000000                          559.000000  548.000000
# 75%        66.000000                          613.000000  599.000000
# max       100.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
#Min score for math is 52 - that's too low
#https://blog.prepscholar.com/whats-the-lowest-sat-score-possible-how-many-get-it
#The lowest possible score for math is 200. 
#look at the row which gives math = 52
sat2017.loc[sat2017['Math'] == 52]
# Out:
#        State  Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland             69                                 536    52   1060

# %%
#Manually calculate the score for math as an estimate
#Math = Total - EBRW
sat2017.loc[20,['Math']] = 1060-536

# %%
#check if it's been replaced
sat2017.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean       39.803922                          569.117647  556.882353
# std        35.276632                           45.666901   47.121395
# min         2.000000                          482.000000  468.000000
# 25%         4.000000                          533.500000  523.500000
# 50%        38.000000                          559.000000  548.000000
# 75%        66.000000                          613.000000  599.000000
# max       100.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
#Summary/Overview of Sat 2018 Data
sat2018.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean       45.745098                          563.686275  556.235294
# std        37.314256                           47.502627   47.772623
# min         2.000000                          480.000000  480.000000
# 25%         4.500000                          534.500000  522.500000
# 50%        52.000000                          552.000000  544.000000
# 75%        77.500000                          610.500000  593.500000
# max       100.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %%
#Summary/Overview of Sat 2019 Data
sat2019.describe()
# Out:
#        Participation Rate        EBRW        Math        Total
# count           51.000000   53.000000   53.000000    53.000000
# mean            49.058824  558.000000  548.471698  1106.528302
# std             38.747600   47.554422   53.785044   100.994784
# min              2.000000  483.000000  445.000000   935.000000
# 25%              5.500000  518.000000  506.000000  1024.000000
# 50%             54.000000  550.000000  545.000000  1097.000000
# 75%             82.000000  610.000000  596.000000  1200.000000
# max            100.000000  636.000000  648.000000  1284.000000

# %%
#Since we intend to merge the data sets by State, we would have to check if unique values of State are the same across data sets
#Remove blank spaces in 'State'
act2017['State'] = act2017['State'].str.replace('\s', '', regex=True).str.lower()
act2018['State'] = act2018['State'].str.replace('\s', '', regex=True).str.lower()
act2019['State'] = act2019['State'].str.replace('\s', '', regex=True).str.lower()
sat2017['State'] = sat2017['State'].str.replace('\s', '', regex=True).str.lower()
sat2018['State'] = sat2018['State'].str.replace('\s', '', regex=True).str.lower()
sat2019['State'] = sat2019['State'].str.replace('\s', '', regex=True).str.lower()

# %%
#Concat and get a unique list of States
states = pd.concat([act2017['State'], act2018['State'], act2019['State'], sat2017['State'], sat2018['State'], sat2019['State']])
states = states.to_frame()
states.head()
# Out:
#       State
# 0  national
# 1   alabama
# 2    alaska
# 3   arizona
# 4  arkansas

# %%
states.value_counts()
# Out:
# State
# maine                 7
# alabama               6
# alaska                6
# nevada                6
# newhampshire          6
# newjersey             6
# newmexico             6
# newyork               6
# northcarolina         6
# northdakota           6
# ohio                  6
# oklahoma              6
# oregon                6
# pennsylvania          6
# rhodeisland           6
# southcarolina         6
# southdakota           6
# tennessee             6
# texas                 6
# utah                  6
# vermont               6
# virginia              6
# washington            6
# westvirginia          6
# wisconsin             6
# nebraska              6
# wyoming               6
# montana               6
# arkansas              6
# arizona               6
# colorado              6
# connecticut           6
# delaware              6
# districtofcolumbia    6
# florida               6
# georgia               6
# hawaii                6
# idaho                 6
# ...

# %%
#Drop rows with < 6 (means didn't appear in all the data sets) - national (2), virginislands (1), puertorico (1)
#maine has 7 - means one of the datasets has it twice; to do it when we merge the data

# %%
act2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  national             60     20.3  20.7     21.4     21.0       21.0
# 1   alabama            100     18.9  18.4     19.7     19.4       19.2
# 2    alaska             65     18.7  19.8     20.4     19.9       19.8
# 3   arizona             62     18.6  19.8     20.1     19.8       19.7
# 4  arkansas            100     18.9  19.0     19.7     19.5       19.4

# %%
#For consistency in data merging later on, would drop these rows
act2017.loc[act2017['State'] == 'maine']
# Out:
#     State  Participation  English  Math  Reading  Science  Composite
# 20  maine              8     24.2  24.0     24.8     23.7       24.3

# %%
act2018.loc[act2018['State'] == 'maine']
# Out:
#     State  Participation  Composite
# 19  maine              7       24.0
# 20  maine              7       24.0

# %%
#since data is the same, we can drop one of it
act2018.drop([19], inplace = True )
act2018.loc[act2018['State'] == 'maine']
# Out:
#     State  Participation  Composite
# 20  maine              7       24.0

# %%
act2018.head()
# Out:
#         State  Participation  Composite
# 0     alabama            100       19.1
# 1      alaska             33       20.8
# 2     arizona             66       19.2
# 3    arkansas            100       19.4
# 4  california             27       22.7

# %%
act2017.head()
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  national             60     20.3  20.7     21.4     21.0       21.0
# 1   alabama            100     18.9  18.4     19.7     19.4       19.2
# 2    alaska             65     18.7  19.8     20.4     19.9       19.8
# 3   arizona             62     18.6  19.8     20.1     19.8       19.7
# 4  arkansas            100     18.9  19.0     19.7     19.5       19.4

# %%
act2017.loc[(act2017['State'] == 'national')|(act2017['State'] == 'virginislands')|(act2017['State'] == 'puertorico')]
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  national             60     20.3  20.7     21.4     21.0       21.0

# %%
act2017.drop([0], inplace = True )
act2017.loc[(act2017['State'] == 'national')|(act2017['State'] == 'virginislands')|(act2017['State'] == 'puertorico')]
#dropped one national
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []

# %%
act2017.head()
# Out:
#         State  Participation  English  Math  Reading  Science  Composite
# 1     alabama            100     18.9  18.4     19.7     19.4       19.2
# 2      alaska             65     18.7  19.8     20.4     19.9       19.8
# 3     arizona             62     18.6  19.8     20.1     19.8       19.7
# 4    arkansas            100     18.9  19.0     19.7     19.5       19.4
# 5  california             31     22.5  22.7     23.1     22.2       22.8

# %%
act2018.loc[(act2018['State'] == 'national')|(act2018['State'] == 'virginislands')|(act2018['State'] == 'puertorico')]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []

# %%
act2019.loc[(act2019['State'] == 'national')|(act2019['State'] == 'virginislands')|(act2019['State'] == 'puertorico')]
# Out:
#        State  Participation  Composite
# 51  national            100       20.7

# %%
act2019.drop([51], inplace = True )
act2019.loc[(act2019['State'] == 'national')|(act2019['State'] == 'virginislands')|(act2019['State'] == 'puertorico')]
#dropped one national
# Out:
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []

# %%
sat2017.loc[(sat2017['State'] == 'national')|(sat2017['State'] == 'virginislands')|(sat2017['State'] == 'puertorico')]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %%
sat2018.loc[(sat2018['State'] == 'national')|(sat2018['State'] == 'virginislands')|(sat2018['State'] == 'puertorico')]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, Total]
# Index: []

# %%
sat2019.loc[(sat2019['State'] == 'national')|(sat2019['State'] == 'virginislands')|(sat2019['State'] == 'puertorico')]
# Out:
#             State  Participation Rate  EBRW  Math  Total
# 39     puertorico                 NaN   483   462    944
# 47  virginislands                 NaN   490   445    935

# %%
sat2019.drop([39, 47], inplace = True )
sat2019.loc[(sat2019['State'] == 'national')|(sat2019['State'] == 'virginislands')|(sat2019['State'] == 'puertorico')]
# Out:
# Empty DataFrame
# Columns: [State, Participation Rate, EBRW, Math, Total]
# Index: []

# %%
sat2019.head()
# Out:
#         State  Participation Rate  EBRW  Math  Total
# 0     alabama                 7.0   583   560   1143
# 1      alaska                41.0   556   541   1097
# 2     arizona                31.0   569   565   1134
# 3    arkansas                 6.0   582   559   1141
# 4  california                63.0   534   531   1065

# %% [markdown]
# ### 7. Rename Columns.
# ### 8. Drop unnecessary rows (if needed).

# %%
#Check column names for all 6 datasets
print(f'2017 ACT: {act2017.columns}\n')
print(f'2018 ACT: {act2018.columns}\n')
print(f'2019 ACT: {act2019.columns}\n')
print(f'2017 SAT: {sat2017.columns}\n')
print(f'2018 SAT: {sat2018.columns}\n')
print(f'2019 SAT: {sat2019.columns}')
# Out:
# 2017 ACT: Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')
#
# 2018 ACT: Index(['State', 'Participation', 'Composite'], dtype='object')
#
# 2019 ACT: Index(['State', 'Participation', 'Composite'], dtype='object')
#
# 2017 SAT: Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#
# 2018 SAT: Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#
# 2019 SAT: Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
act2017.head()
# Out:
#         State  Participation  English  Math  Reading  Science  Composite
# 1     alabama            100     18.9  18.4     19.7     19.4       19.2
# 2      alaska             65     18.7  19.8     20.4     19.9       19.8
# 3     arizona             62     18.6  19.8     20.1     19.8       19.7
# 4    arkansas            100     18.9  19.0     19.7     19.5       19.4
# 5  california             31     22.5  22.7     23.1     22.2       22.8

# %%
#Rename the columns

act2017.rename(columns={'State':'state',
                         'Participation':'act_participation_rate_2017',
                         'English':'act_english_avg_score_2017',
                         'Math':'act_math_avg_score_2017',
                        'Reading':'act_reading_avg_score_2017',
                        'Science':'act_science_avg_score_2017',
                         'Composite':'act_composite_avg_score_2017'},inplace=True)

act2018.rename(columns={'State':'state',
                         'Participation':'act_participation_rate_2018',
                        'Composite':'act_composite_avg_score_2018'},inplace=True)
                        

act2019.rename(columns={'State':'state',
                         'Participation':'act_participation_rate_2019',
                        'Composite':'act_composite_avg_score_2019'},inplace=True)
    
sat2017.rename(columns={'State':'state',
                         'Participation':'sat_participation_rate_2017',
                         'Evidence-Based Reading and Writing':'sat_ebrw_avg_score_2017',
                         'Math':'sat_math_avg_score_2017',
                         'Total':'sat_total_avg_score_2017'},inplace=True)

sat2018.rename(columns={'State':'state',
                         'Participation':'sat_participation_rate_2018',
                         'Evidence-Based Reading and Writing':'sat_ebrw_avg_score_2018',
                         'Math':'sat_math_avg_score_2018',
                         'Total':'sat_total_avg_score_2018'},inplace=True)

sat2019.rename(columns={'State':'state',
                         'Participation Rate':'sat_participation_rate_2019',
                         'EBRW':'sat_ebrw_avg_score_2019',
                         'Math':'sat_math_avg_score_2019',
                         'Total':'sat_total_avg_score_2019'},inplace=True)

# %%
#Check column names for all 6 datasets
print(f'2017 ACT: {act2017.columns}\n')
print(f'2018 ACT: {act2018.columns}\n')
print(f'2019 ACT: {act2019.columns}\n')
print(f'2017 SAT: {sat2017.columns}\n')
print(f'2018 SAT: {sat2018.columns}\n')
print(f'2019 SAT: {sat2019.columns}')
# Out:
# 2017 ACT: Index(['state', 'act_participation_rate_2017', 'act_english_avg_score_2017',
#        'act_math_avg_score_2017', 'act_reading_avg_score_2017',
#        'act_science_avg_score_2017', 'act_composite_avg_score_2017'],
#       dtype='object')
#
# 2018 ACT: Index(['state', 'act_participation_rate_2018', 'act_composite_avg_score_2018'], dtype='object')
#
# 2019 ACT: Index(['state', 'act_participation_rate_2019', 'act_composite_avg_score_2019'], dtype='object')
#
# 2017 SAT: Index(['state', 'sat_participation_rate_2017', 'sat_ebrw_avg_score_2017',
#        'sat_math_avg_score_2017', 'sat_total_avg_score_2017'],
#       dtype='object')
#
# 2018 SAT: Index(['state', 'sat_participation_rate_2018', 'sat_ebrw_avg_score_2018',
#        'sat_math_avg_score_2018', 'sat_total_avg_score_2018'],
#       dtype='object')
#
# 2019 SAT: Index(['state', 'sat_participation_rate_2019', 'sat_ebrw_avg_score_2019',
#        'sat_math_avg_score_2019', 'sat_total_avg_score_2019'],
# ...

# %% [markdown]
# ### 9. Merge dataframes that can be merged.

# %%
#select the columns to merge
list_to_merge = [act2017, act2018, act2019, sat2017, sat2018, sat2019]
merged = reduce(lambda left,right: pd.merge(left,right,on='state'),list_to_merge)

# %%
merged.head()
# Out:
#         state  act_participation_rate_2017  act_english_avg_score_2017  \
# 0     alabama                          100                        18.9
# 1      alaska                           65                        18.7
# 2     arizona                           62                        18.6
# 3    arkansas                          100                        18.9
# 4  california                           31                        22.5
#
#    act_math_avg_score_2017  act_reading_avg_score_2017  \
# 0                     18.4                        19.7
# 1                     19.8                        20.4
# 2                     19.8                        20.1
# 3                     19.0                        19.7
# 4                     22.7                        23.1
#
#    act_science_avg_score_2017  act_composite_avg_score_2017  \
# 0                        19.4                          19.2
# 1                        19.9                          19.8
# ...

# %%
merged.shape
#51 States
# Out:
# (51, 23)

# %%
merged.head()
# Out:
#         state  act_participation_rate_2017  act_english_avg_score_2017  \
# 0     alabama                          100                        18.9
# 1      alaska                           65                        18.7
# 2     arizona                           62                        18.6
# 3    arkansas                          100                        18.9
# 4  california                           31                        22.5
#
#    act_math_avg_score_2017  act_reading_avg_score_2017  \
# 0                     18.4                        19.7
# 1                     19.8                        20.4
# 2                     19.8                        20.1
# 3                     19.0                        19.7
# 4                     22.7                        23.1
#
#    act_science_avg_score_2017  act_composite_avg_score_2017  \
# 0                        19.4                          19.2
# 1                        19.9                          19.8
# ...

# %%
merged.describe()
# Out:
#        act_participation_rate_2017  act_english_avg_score_2017  \
# count                    51.000000                   51.000000
# mean                     65.254902                   20.931373
# std                      32.140842                    2.353677
# min                       8.000000                   16.300000
# 25%                      31.000000                   19.000000
# 50%                      69.000000                   20.700000
# 75%                     100.000000                   23.300000
# max                     100.000000                   25.500000
#
#        act_math_avg_score_2017  act_reading_avg_score_2017  \
# count                51.000000                   51.000000
# mean                 21.182353                   22.013725
# std                   1.981989                    2.067271
# min                  18.000000                   18.100000
# 25%                  19.400000                   20.450000
# ...

# %%
merged.isnull().sum()
# Out:
# state                           0
# act_participation_rate_2017     0
# act_english_avg_score_2017      0
# act_math_avg_score_2017         0
# act_reading_avg_score_2017      0
# act_science_avg_score_2017      0
# act_composite_avg_score_2017    1
# act_participation_rate_2018     0
# act_composite_avg_score_2018    0
# act_participation_rate_2019     0
# act_composite_avg_score_2019    0
# sat_participation_rate_2017     0
# sat_ebrw_avg_score_2017         0
# sat_math_avg_score_2017         0
# sat_total_avg_score_2017        0
# sat_participation_rate_2018     0
# sat_ebrw_avg_score_2018         0
# sat_math_avg_score_2018         0
# sat_total_avg_score_2018        0
# sat_participation_rate_2019     0
# sat_ebrw_avg_score_2019         0
# sat_math_avg_score_2019         0
# sat_total_avg_score_2019        0
# dtype: int64

# %%
#check the data where 'act_composite_avg_score_2017' is null
merged[merged['act_composite_avg_score_2017'].isna()]
# Out:
#       state  act_participation_rate_2017  act_english_avg_score_2017  \
# 50  wyoming                          100                        19.4
#
#     act_math_avg_score_2017  act_reading_avg_score_2017  \
# 50                     19.8                        20.8
#
#     act_science_avg_score_2017  act_composite_avg_score_2017  \
# 50                        20.6                           NaN
#
#     act_participation_rate_2018  act_composite_avg_score_2018  \
# 50                          100                          20.0
#
#     act_participation_rate_2019  ...  sat_math_avg_score_2017  \
# 50                          100  ...                      604
#
#     sat_total_avg_score_2017  sat_participation_rate_2018  \
# 50                      1230                            3
#
#     sat_ebrw_avg_score_2018  sat_math_avg_score_2018  \
# 50                      633                      625
#
#     sat_total_avg_score_2018  sat_participation_rate_2019  \
# ...

# %%
#Manually calculate the missing data to use mean (of eng, math, reading, science as an average)
merged[merged['act_composite_avg_score_2017'].isna()] = (19.4+19.8+20.8+20.6)/4

# %%
merged['act_composite_avg_score_2017'] = pd.to_numeric(merged['act_composite_avg_score_2017'], errors = 'coerce')
#sat2019['Participation Rate'] =pd.to_numeric(sat2019["Participation Rate"], downcast='float', errors = 'coerce')

# %%
merged.isnull().sum()
# Out:
# state                           0
# act_participation_rate_2017     0
# act_english_avg_score_2017      0
# act_math_avg_score_2017         0
# act_reading_avg_score_2017      0
# act_science_avg_score_2017      0
# act_composite_avg_score_2017    0
# act_participation_rate_2018     0
# act_composite_avg_score_2018    0
# act_participation_rate_2019     0
# act_composite_avg_score_2019    0
# sat_participation_rate_2017     0
# sat_ebrw_avg_score_2017         0
# sat_math_avg_score_2017         0
# sat_total_avg_score_2017        0
# sat_participation_rate_2018     0
# sat_ebrw_avg_score_2018         0
# sat_math_avg_score_2018         0
# sat_total_avg_score_2018        0
# sat_participation_rate_2019     0
# sat_ebrw_avg_score_2019         0
# sat_math_avg_score_2019         0
# sat_total_avg_score_2019        0
# dtype: int64

# %%
merged.dtypes
# Out:
# state                            object
# act_participation_rate_2017     float64
# act_english_avg_score_2017      float64
# act_math_avg_score_2017         float64
# act_reading_avg_score_2017      float64
# act_science_avg_score_2017      float64
# act_composite_avg_score_2017    float64
# act_participation_rate_2018     float64
# act_composite_avg_score_2018    float64
# act_participation_rate_2019     float64
# act_composite_avg_score_2019    float64
# sat_participation_rate_2017     float64
# sat_ebrw_avg_score_2017         float64
# sat_math_avg_score_2017         float64
# sat_total_avg_score_2017        float64
# sat_participation_rate_2018     float64
# sat_ebrw_avg_score_2018         float64
# sat_math_avg_score_2018         float64
# sat_total_avg_score_2018        float64
# sat_participation_rate_2019     float64
# sat_ebrw_avg_score_2019         float64
# sat_math_avg_score_2019         float64
# sat_total_avg_score_2019        float64
# dtype: object

# %% [markdown]
# ### 10. Save your cleaned and merged dataframes as csv files.

# %%
merged.to_csv('datafile.csv', encoding ='utf-8', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |act_participation_rate_2017|float|ACT|ACT's Participation Rate in 2017|
# |act_english_avg_score_2017|float|ACT|ACT's Average Score for English in 2017|
# |act_math_avg_score_2017|float|ACT|ACT's Average Score for Math in 2017|
# |act_reading_avg_score_2017|float|ACT|ACT's Average Score for Reading in 2017|
# |act_science_avg_score_2017|float|ACT|ACT's Average Score for Science in 2017|
# |act_composite_avg_score_2017|float|ACT|ACT's Average Composite Score in 2017|
# |act_participation_rate_2018|float|ACT|ACT's Participation Rate in 2018|
# |act_composite_2018|float|ACT|ACT's Average Composite Score in 2018|
# |act_participation_rate_2019|float|ACT|ACT's Participation Rate in 2019|
# |act_composite_2019|float|ACT|ACT's Average Composite Score in 2019|
# |sat_participation_rate_2017|float|SAT|SAT's Participation Rate in 2017|
# |sat_ebrw_avg_score_2017|float|SAT|SAT's Average Score for Evidence-based Reading and Writing in 2017|
# |sat_math_avg_score_2017|float|SAT|SAT's Average Score for Math in 2017|
# |sat_total_avg_score_2017|float|SAT|SAT's Average Score for Total in 2017|
# |sat_participation_rate_2018|float|SAT|SAT's Participation Rate in 2018|
# |sat_ebrw_avg_score_2018|float|SAT|SAT's Average Score for Evidence-based Reading and Writing in 2018|
# |sat_math_avg_score_2018|float|SAT|SAT's Average Score for Math in 2018|
# |sat_total_avg_score_2018|float|SAT|SAT's Average Score for Total in 2018|
# |sat_participation_rate_2019|float|SAT|SAT's Participation Rate in 2019|
# |sat_ebrw_avg_score_2019|float|SAT|SAT's Average Score for Evidence-based Reading and Writing in 2019|
# |sat_math_avg_score_2019|float|SAT|SAT's Average Score for Math in 2019|
# |sat_total_avg_score_2019|float|SAT|SAT's Average Score for Total in 2019|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Summary Statistics
merged.describe()
# Out:
#        act_participation_rate_2017  act_english_avg_score_2017  \
# count                    51.000000                   51.000000
# mean                     63.689216                   20.946078
# std                      32.358584                    2.346249
# min                       8.000000                   16.300000
# 25%                      31.000000                   19.000000
# 50%                      67.000000                   20.700000
# 75%                     100.000000                   23.300000
# max                     100.000000                   25.500000
#
#        act_math_avg_score_2017  act_reading_avg_score_2017  \
# count                51.000000                   51.000000
# mean                 21.189216                   22.000980
# std                   1.977709                    2.076884
# min                  18.000000                   18.100000
# 25%                  19.400000                   20.400000
# ...

# %%
merged.select_dtypes(include = ['float']).head()
# Out:
#    act_participation_rate_2017  act_english_avg_score_2017  \
# 0                        100.0                        18.9
# 1                         65.0                        18.7
# 2                         62.0                        18.6
# 3                        100.0                        18.9
# 4                         31.0                        22.5
#
#    act_math_avg_score_2017  act_reading_avg_score_2017  \
# 0                     18.4                        19.7
# 1                     19.8                        20.4
# 2                     19.8                        20.1
# 3                     19.0                        19.7
# 4                     22.7                        23.1
#
#    act_science_avg_score_2017  act_composite_avg_score_2017  \
# 0                        19.4                          19.2
# 1                        19.9                          19.8
# 2                        19.8                          19.7
# ...

# %%
#Creating the column names for dictionary
column_names = merged.select_dtypes(include = ['float']).columns.tolist()[1:] #remove the first column as it is an object type (State)
column_names
# Out:
# ['act_english_avg_score_2017',
#  'act_math_avg_score_2017',
#  'act_reading_avg_score_2017',
#  'act_science_avg_score_2017',
#  'act_composite_avg_score_2017',
#  'act_participation_rate_2018',
#  'act_composite_avg_score_2018',
#  'act_participation_rate_2019',
#  'act_composite_avg_score_2019',
#  'sat_participation_rate_2017',
#  'sat_ebrw_avg_score_2017',
#  'sat_math_avg_score_2017',
#  'sat_total_avg_score_2017',
#  'sat_participation_rate_2018',
#  'sat_ebrw_avg_score_2018',
#  'sat_math_avg_score_2018',
#  'sat_total_avg_score_2018',
#  'sat_participation_rate_2019',
#  'sat_ebrw_avg_score_2019',
#  'sat_math_avg_score_2019',
#  'sat_total_avg_score_2019']

# %%
#Creating the dictionary
sd = {c:std_dev(merged[c]) for c in column_names}
sd
# Out:
# {'act_english_avg_score_2017': 2.323132670686981,
#  'act_math_avg_score_2017': 1.958223327544194,
#  'act_reading_avg_score_2017': 2.056422035441856,
#  'act_science_avg_score_2017': 3.1529603818554666,
#  'act_composite_avg_score_2017': 2.001444595548517,
#  'act_participation_rate_2018': 33.742020145376074,
#  'act_composite_avg_score_2018': 2.0887769710789255,
#  'act_participation_rate_2019': 34.0512460951215,
#  'act_composite_avg_score_2019': 2.168180200662569,
#  'sat_participation_rate_2017': 34.65460388678231,
#  'sat_ebrw_avg_score_2017': 88.02918722087672,
#  'sat_math_avg_score_2017': 87.46975975494531,
#  'sat_total_avg_score_2017': 177.75226381519414,
#  'sat_participation_rate_2018': 36.63275208835789,
#  'sat_ebrw_avg_score_2018': 88.12734273255444,
#  'sat_math_avg_score_2018': 87.40222905834581,
#  'sat_total_avg_score_2018': 177.35598792622477,
#  'sat_participation_rate_2019': 38.03439137085242,
#  'sat_ebrw_avg_score_2019': 87.25175523076697,
# ...

# %% [markdown]
# #### Trends

# %% [markdown]
# #### 1. Participation Rate
# ##### 1.1 States with higher participation rates from 2017 to 2019 for ACT (with comparison to participation rate of SAT)

# %%
#function to display dataframes side by side
def dsbs(*args):
    html_str=''
    for df in args:
        html_str+=df.to_html()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
act1 = merged[['state','act_participation_rate_2017', 'sat_participation_rate_2017']].sort_values(by=['act_participation_rate_2017'],ascending=False).head(10)
act2 = merged[['state','act_participation_rate_2018', 'sat_participation_rate_2018']].sort_values(by=['act_participation_rate_2018'],ascending=False).head(10)
act3 = merged[['state','act_participation_rate_2019','sat_participation_rate_2019']].sort_values(by=['act_participation_rate_2019'],ascending=False).head(10)

dsbs(act1,act2,act3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>act_participation_rate_2017</th>
#       <th>sat_participation_rate_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>alabama</td>
#       <td>100.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>kentucky</td>
#       <td>100.0</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>wisconsin</td>
#       <td>100.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>utah</td>
#       <td>100.0</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>tennessee</td>
#       <td>100.0</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>southcarolina</td>
#       <td>100.0</td>
#       <td>50.0</td>
#     </tr>
#     <tr>
#       <th>36</th>
# ...

# %% [markdown]
# **Trends:**
#
# Alabama and Kentucky have the top 2 participation rate from 2017 to 2018.
#
# States with high participation in ACT seems to have lower participation on SAT.

# %% [markdown]
# #### 1.2. States with higher participation rates from 2017 to 2019 for SAT (with comparison to participation rate of ACT)

# %%
sat1 = merged[['state','sat_participation_rate_2017', 'act_participation_rate_2017']].sort_values(by=['sat_participation_rate_2017'],ascending=False).head(10)
sat2 = merged[['state','sat_participation_rate_2018', 'act_participation_rate_2018']].sort_values(by=['sat_participation_rate_2018'],ascending=False).head(10)
sat3 = merged[['state','sat_participation_rate_2019', 'act_participation_rate_2019']].sort_values(by=['sat_participation_rate_2019'],ascending=False).head(10)

dsbs(sat1,sat2,sat3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>sat_participation_rate_2017</th>
#       <th>act_participation_rate_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>22</th>
#       <td>michigan</td>
#       <td>100.0</td>
#       <td>29.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>connecticut</td>
#       <td>100.0</td>
#       <td>31.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>delaware</td>
#       <td>100.0</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>districtofcolumbia</td>
#       <td>100.0</td>
#       <td>32.0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>newhampshire</td>
#       <td>96.0</td>
#       <td>18.0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>maine</td>
#       <td>95.0</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Trends:**
#
# Michigan, Connecticut and Delaware has 100% participation for all 3 years

# %% [markdown]
# ##### 1.3 States with lower participation rates from 2017 to 2019 for ACT (with comparison to participation rate of SAT)

# %%
act1 = merged[['state','act_participation_rate_2017', 'sat_participation_rate_2017']].sort_values(by=['act_participation_rate_2017'],ascending=True).head(10)
act2 = merged[['state','act_participation_rate_2018', 'sat_participation_rate_2018']].sort_values(by=['act_participation_rate_2018'],ascending=True).head(10)
act3 = merged[['state','act_participation_rate_2019','sat_participation_rate_2019']].sort_values(by=['act_participation_rate_2019'],ascending=True).head(10)

dsbs(act1,act2,act3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>act_participation_rate_2017</th>
#       <th>sat_participation_rate_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>19</th>
#       <td>maine</td>
#       <td>8.00</td>
#       <td>95.00</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>newhampshire</td>
#       <td>18.00</td>
#       <td>96.00</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>delaware</td>
#       <td>18.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>20.15</td>
#       <td>20.15</td>
#       <td>20.15</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>rhodeisland</td>
#       <td>21.00</td>
#       <td>71.00</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>pennsylvania</td>
#       <td>23.00</td>
#       <td>65.00</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Trends:**
#
# Michigan, Connecticut and Delaware has 100% participation for all 3 years.
#
# Maine has the lowest act participation rate from 2017 to 2019; in comparison, it has high participation rate for SAT.

# %% [markdown]
# ##### 1.4 States with lower participation rates from 2017 to 2019 for SAT (with comparison to participation rate of ACT)

# %%
sat1 = merged[['state','sat_participation_rate_2017', 'act_participation_rate_2017']].sort_values(by=['sat_participation_rate_2017'],ascending=True).head(10)
sat2 = merged[['state','sat_participation_rate_2018', 'act_participation_rate_2018']].sort_values(by=['sat_participation_rate_2018'],ascending=True).head(10)
sat3 = merged[['state','sat_participation_rate_2019', 'act_participation_rate_2019']].sort_values(by=['sat_participation_rate_2019'],ascending=True).head(10)

dsbs(sat1,sat2,sat3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>sat_participation_rate_2017</th>
#       <th>act_participation_rate_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>34</th>
#       <td>northdakota</td>
#       <td>2.0</td>
#       <td>98.0</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>mississippi</td>
#       <td>2.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>iowa</td>
#       <td>2.0</td>
#       <td>67.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>missouri</td>
#       <td>3.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>utah</td>
#       <td>3.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>arkansas</td>
#       <td>3.0</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>41</th>
# ...

# %% [markdown]
# **Trends:**
#
# Northdakota has the lowest act participation rate from 2017 to 2019; in comparison, it has high participation rate for SAT.

# %% [markdown]
# ##### 1.5 Average/Median Participation Rate for ACT and SAT across the years

# %%
#Get the average for each year
sat_avg_participation2017 = merged['sat_participation_rate_2017'].mean()
sat_avg_participation2018 = merged['sat_participation_rate_2018'].mean()
sat_avg_participation2019 = merged['sat_participation_rate_2019'].mean()
sat_median_participation2017 = merged['sat_participation_rate_2017'].median()
sat_median_participation2018 = merged['sat_participation_rate_2018'].median()
sat_median_participation2019 = merged['sat_participation_rate_2019'].median()

act_avg_participation2017 = merged['act_participation_rate_2017'].mean()
act_avg_participation2018 = merged['act_participation_rate_2018'].mean()
act_avg_participation2019 = merged['act_participation_rate_2019'].mean()
act_median_participation2017 = merged['act_participation_rate_2017'].median()
act_median_participation2018 = merged['act_participation_rate_2018'].median()
act_median_participation2019 = merged['act_participation_rate_2019'].median()

# %%
participation_summary = pd.DataFrame({"Year": ['2017', '2018', '2019'], "SAT_avg_participation": [sat_avg_participation2017, sat_avg_participation2018, sat_avg_participation2019], "SAT_median_participation": [sat_median_participation2017, sat_median_participation2018, sat_median_participation2019], "ACT_avg_participation": [act_avg_participation2017, act_avg_participation2018, act_avg_participation2019], "ACT_median_participation": [act_median_participation2017, act_median_participation2018, act_median_participation2019]})

# %%
participation_summary
# Out:
#    Year  SAT_avg_participation  SAT_median_participation  \
# 0  2017              40.140196                      38.0
# 1  2018              46.081373                      52.0
# 2  2019              49.395098                      54.0
#
#    ACT_avg_participation  ACT_median_participation
# 0              63.689216                      67.0
# 1              60.159804                      65.0
# 2              58.336275                      53.0

# %% [markdown]
# **Trends:**
#
# Average/median participation for SAT increased, ACT decreased

# %% [markdown]
# #### 2. Highest Mean Total Composite Score
# ##### 2.1 States with highest average score from 2017 to 2019 for SAT (with comparison to ACT)

# %%
act1 = merged[['state','act_composite_avg_score_2017', 'sat_total_avg_score_2017']].sort_values(by=['sat_total_avg_score_2017'],ascending=False).head()
act2 = merged[['state','act_composite_avg_score_2018', 'sat_total_avg_score_2018']].sort_values(by=['sat_total_avg_score_2018'],ascending=False).head()
act3 = merged[['state','act_composite_avg_score_2019', 'sat_total_avg_score_2019']].sort_values(by=['sat_total_avg_score_2019'],ascending=False).head()

dsbs(act1,act2,act3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>act_composite_avg_score_2017</th>
#       <th>sat_total_avg_score_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23</th>
#       <td>minnesota</td>
#       <td>21.5</td>
#       <td>1295.0</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>wisconsin</td>
#       <td>20.5</td>
#       <td>1291.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>iowa</td>
#       <td>21.9</td>
#       <td>1275.0</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>missouri</td>
#       <td>20.4</td>
#       <td>1271.0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>kansas</td>
#       <td>21.7</td>
#       <td>1260.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
# ...

# %% [markdown]
# ##### 2.2 States with highest average score from 2017 to 2019 for ACT (with comparison to SAT)

# %%
sat1 = merged[['state','sat_total_avg_score_2017', 'act_composite_avg_score_2017']].sort_values(by=['sat_total_avg_score_2017'],ascending=False).head()
sat2 = merged[['state','sat_total_avg_score_2018', 'act_composite_avg_score_2018']].sort_values(by=['sat_total_avg_score_2018'],ascending=False).head()
sat3 = merged[['state','sat_total_avg_score_2019', 'act_composite_avg_score_2019']].sort_values(by=['sat_total_avg_score_2019'],ascending=False).head()

dsbs(sat1,sat2,sat3)
# Out:
# <table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>sat_total_avg_score_2017</th>
#       <th>act_composite_avg_score_2017</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>23</th>
#       <td>minnesota</td>
#       <td>1295.0</td>
#       <td>21.5</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>wisconsin</td>
#       <td>1291.0</td>
#       <td>20.5</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>iowa</td>
#       <td>1275.0</td>
#       <td>21.9</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>missouri</td>
#       <td>1271.0</td>
#       <td>20.4</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>kansas</td>
#       <td>1260.0</td>
#       <td>21.7</td>
#     </tr>
#   </tbody>
# </table style="display:inline"><table style="display:inline" border="1" class="dataframe">
#   <thead>
# ...

# %% [markdown]
# ##### 2.3 Average/Median Total Score for ACT and SAT across the years

# %%
#Get the average for each year
act_avg_score2017 = merged['act_composite_avg_score_2017'].mean()
act_avg_score2018 = merged['act_composite_avg_score_2018'].mean()
act_avg_score2019 = merged['act_composite_avg_score_2019'].mean()
act_median_score2017 = merged['act_composite_avg_score_2017'].median()
act_median_score2018 = merged['act_composite_avg_score_2018'].median()
act_median_score2019 = merged['act_composite_avg_score_2019'].median()

sat_avg_score2017 = merged['sat_total_avg_score_2017'].mean()
sat_avg_score2018 = merged['sat_total_avg_score_2018'].mean()
sat_avg_score2019 = merged['sat_total_avg_score_2019'].mean()
sat_median_score2017 = merged['sat_total_avg_score_2017'].median()
sat_median_score2018 = merged['sat_total_avg_score_2018'].median()
sat_median_score2019 = merged['sat_total_avg_score_2019'].median()

sat_avg_math_score2017 = merged['sat_math_avg_score_2017'].mean()
sat_avg_math_score2018 = merged['sat_math_avg_score_2018'].mean()
sat_avg_math_score2019 = merged['sat_math_avg_score_2019'].mean()
sat_median_math_score2017 = merged['sat_math_avg_score_2017'].median()
sat_median_math_score2018 = merged['sat_math_avg_score_2018'].median()
sat_median_math_score2019 = merged['sat_math_avg_score_2019'].median()

sat_avg_ebrw_score2017 = merged['sat_ebrw_avg_score_2017'].mean()
sat_avg_ebrw_score2018 = merged['sat_ebrw_avg_score_2018'].mean()
sat_avg_ebrw_score2019 = merged['sat_ebrw_avg_score_2019'].mean()
sat_median_ebrw_score2017 = merged['sat_ebrw_avg_score_2017'].median()
sat_median_ebrw_score2018 = merged['sat_ebrw_avg_score_2018'].median()
sat_median_ebrw_score2019 = merged['sat_ebrw_avg_score_2019'].median()

# %%
score_summary = pd.DataFrame({"Year": ['2017', '2018', '2019'], 
                              "ACT_avg_score": [act_avg_score2017, act_avg_score2018, act_avg_score2019], 
                              "ACT_median_score": [act_median_score2017, act_median_score2018, act_median_score2019], 
                              "SAT_avg_score": [sat_avg_score2017, sat_avg_score2018, sat_avg_score2019], 
                              "SAT_median_score": [sat_median_score2017, sat_median_score2018, sat_median_score2019], 
                              "SAT_avg_math_score": [sat_avg_math_score2017, sat_avg_math_score2018, sat_avg_math_score2019], 
                              "SAT_median_math_score": [sat_median_math_score2017, sat_median_math_score2018, sat_median_math_score2019],
                             "SAT_avg_ebrw_score": [sat_avg_ebrw_score2017, sat_avg_ebrw_score2018, sat_avg_ebrw_score2019],
                             "SAT_median_ebrw_score": [sat_median_ebrw_score2017, sat_median_ebrw_score2018, sat_median_ebrw_score2019]})

# %%
score_summary
# Out:
#    Year  ACT_avg_score  ACT_median_score  SAT_avg_score  SAT_median_score  \
# 0  2017      21.518627              21.4    1102.375490            1102.0
# 1  2018      21.499020              21.3    1095.767647            1094.0
# 2  2019      21.471569              21.1    1089.199020            1097.0
#
#    SAT_avg_math_score  SAT_median_math_score  SAT_avg_ebrw_score  \
# 0          545.434314                  541.0          557.238235
# 1          544.375490                  543.0          551.669608
# 2          540.532353                  545.0          548.983333
#
#    SAT_median_ebrw_score
# 0                  558.0
# 1                  550.0
# 2                  550.0

# %%
import re

def normalize(x, lower, upper):
    x = re.findall('\d+.\d|$', str(x))

    try:
        value = (float(x[0])-lower)/(upper-lower)
        if (value > 1) | (value < 0):
            return np.nan
        return value
    except:
        return np.nan

# %%
#normalize ACT and SAT scores
score_summary['ACT_avg_score_norm'] = score_summary.apply(lambda x: normalize(x['ACT_avg_score'], 1, 36), axis = 1)
score_summary['SAT_avg_score_norm'] = score_summary.apply(lambda x: normalize(x['SAT_avg_score'], 400, 1600), axis = 1)

score_summary['ACT_med_score_norm'] = score_summary.apply(lambda x: normalize(x['ACT_median_score'], 1, 36), axis = 1)
score_summary['SAT_med_score_norm'] = score_summary.apply(lambda x: normalize(x['SAT_median_score'], 400, 1600), axis = 1)

# %% [markdown]
# **Trends:**
#
# Average scores for SAT and SAT math did not increase.
#
# Median score for SAT math did increase.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### 3. Visualizing
# ##### 3.1 Participation Rates

# %%
plt.figure(figsize = (5,5))

plt.title('2017 to 2019 Participation Rate', fontsize = 16)
plt.scatter(x=merged['act_participation_rate_2017'], 
            y=merged['sat_participation_rate_2017'], 
           marker = 'o', color = 'dimgrey', label = '2017')
plt.legend(loc = 'upper right', frameon=True, fontsize = 14);

plt.scatter(x=merged['act_participation_rate_2018'], 
            y=merged['sat_participation_rate_2018'], 
           marker = 'o', color = 'coral', label = '2018')
plt.legend(loc = 'upper right', frameon=True, fontsize = 14);

plt.scatter(x=merged['act_participation_rate_2019'], 
            y=merged['sat_participation_rate_2019'], 
           marker = 'o', color = 'darkgoldenrod', label = '2019')
plt.legend(loc = 'upper right', frameon=True, fontsize = 14);

plt.xlabel("ACT", fontsize = 14)
plt.ylabel("SAT", fontsize = 14);

# %%
# Establish figure size.
plt.figure(figsize = (16,5))
# We can create subplots, which allows us to have multiple subplots in the same plot.
# plt.subplot(3, 1, 1) means we have 3 rows, 1 column, and are referencing plot 1.
ax1 = plt.subplot(1, 3, 1)
ax1.set_title('2017 Participation Rate', fontsize = 16)
ax1.scatter(x=merged['act_participation_rate_2017'], 
            y=merged['sat_participation_rate_2017'], 
           marker = 'o', color = 'dimgrey', label = '2017')
ax1.set_xlabel('ACT', fontsize = 14)
ax1.set_ylabel('SAT', fontsize = 14)

# plt.subplot(3, 1, 2) means we have 3 rows, 1 column, and are referencing plot 2.
ax2 = plt.subplot(1, 3, 2, sharex = ax1)
ax2.set_title('2018 Participation Rate', fontsize = 16)
ax2.scatter(x=merged['act_participation_rate_2018'], 
            y=merged['sat_participation_rate_2018'], 
           marker = 'o', color = 'coral', label = '2018');

ax2.set_xlabel('ACT', fontsize = 14)
ax2.set_ylabel('SAT', fontsize = 14)

# plt.subplot(3, 1, 3) means we have 3 rows, 1 column, and are referencing plot 3.
ax3 = plt.subplot(1, 3, 3, sharex = ax2)
ax3.set_title('2019 Participation Rate', fontsize = 16)
ax3.scatter(x=merged['act_participation_rate_2019'], 
            y=merged['sat_participation_rate_2019'], 
           marker = 'o', color = 'darkgoldenrod', label = '2019');
ax3.set_xlabel('ACT', fontsize = 14)
ax3.set_ylabel('SAT', fontsize = 14);

# %%
participation_summary.head()
# Out:
#    Year  SAT_avg_participation  SAT_median_participation  \
# 0  2017              40.140196                      38.0
# 1  2018              46.081373                      52.0
# 2  2019              49.395098                      54.0
#
#    ACT_avg_participation  ACT_median_participation
# 0              63.689216                      67.0
# 1              60.159804                      65.0
# 2              58.336275                      53.0

# %%
# using subplot function and creating plot one
fig, ax = plt.subplots(figsize=(20, 8))

plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(participation_summary['Year'],participation_summary['ACT_avg_participation'], color = 'blue', marker = 'o', linewidth=4, label = 'ACT')
plt.plot(participation_summary['Year'],participation_summary['SAT_avg_participation'], color = 'purple', marker = 'o', linewidth=4, label = 'SAT')
plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


plt.title('Average Participation Rate', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Participation Rate', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
 
# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
 
plt.plot(participation_summary['Year'],participation_summary['ACT_median_participation'], color = 'blue', marker = 'o', linewidth=4, label = 'ACT', linestyle='dashed')
plt.plot(participation_summary['Year'],participation_summary['SAT_median_participation'], color = 'purple', marker = 'o', linewidth=4, label = 'SAT', linestyle='dashed')
plt.title('Median Participation Rate', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Participation Rate', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


# show plot
plt.show()

# %% [markdown]
# **Trends:**
#
# Participation rates dropped for ACT, increased for SAT for both Average and Median.

# %% [raw]
# act_participation = merged.loc[:,['state','act_participation_rate_2017','act_participation_rate_2018','act_participation_rate_2019']]
# sat_participation = merged.loc[:,['state','sat_participation_rate_2017','sat_participation_rate_2018','sat_participation_rate_2019']]
#
# boxprops = dict(linewidth=5, color='blue')
# medianprops = dict(linewidth=5, color='blue')
# boxprops2 = dict(linewidth=5, color='purple')
# medianprops2 = dict(linewidth=5, color='purple')
#
# #create figure
# fig = plt.figure()
#
# #set subplots
# ax0 = fig.add_subplot(1,2,1)
# ax1 = fig.add_subplot(1,2,2)
#
# #ax0
# act_participation.plot(kind='box',figsize=(30,10), color = 'blue', ax = ax0, fontsize=16, boxprops=boxprops, medianprops=medianprops)
# ax0.set_title('ACT Participation Rates', fontsize = 25)
# ax0.set_ylabel('Participation Rates', fontsize = 20)
# ax0.set_xlabel('ACT', fontsize = 20)
# ax0.grid(False)
#
#
# sat_participation.plot(kind='box',figsize=(30,10), color = 'purple', ax = ax1,fontsize=16, boxprops=boxprops2, medianprops=medianprops2)
# ax1.set_title('SAT Participation Rates', fontsize = 25)
# ax1.set_ylabel('Participation Rates', fontsize = 20)
# ax1.set_xlabel('SAT', fontsize = 20)
# ax1.grid(False)

# %% [markdown]
# **Trends:**
#
# The overall distribution (or spread) for participation rate for ACT decreased.
#
# The overall distribution (or spread) for participation rate for SAT increased.

# %% [markdown]
# ##### 3.2 Scores (ACT and SAT)

# %%
# using subplot function and creating plot one
fig, ax = plt.subplots(figsize=(20, 8))

plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(score_summary['Year'],score_summary['ACT_avg_score'], color = 'blue', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['ACT_median_score'], color = 'blue', marker = 'o', linewidth=4, label ='Median', linestyle='dashed')
plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


plt.title('ACT Score', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Score', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(False)

# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
 
plt.plot(score_summary['Year'],score_summary['SAT_avg_score'], color = 'purple', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['SAT_median_score'], color = 'purple', marker = 'o', linewidth=4, label = 'Median', linestyle='dashed')
plt.title('SAT Score', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Score', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc = 'upper right', frameon=False, fontsize = 16);
plt.grid(False)

# show plot
plt.show()

# %%
# using subplot function and creating plot one
fig, ax = plt.subplots(figsize=(20, 8))

plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(score_summary['Year'],score_summary['ACT_avg_score_norm'], color = 'blue', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['ACT_med_score_norm'], color = 'blue', marker = 'o', linewidth=4, label ='Median', linestyle='dashed')
plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


plt.title('ACT Score', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Score', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(False)

# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
 
plt.plot(score_summary['Year'],score_summary['SAT_avg_score_norm'], color = 'purple', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['SAT_med_score_norm'], color = 'purple', marker = 'o', linewidth=4, label = 'Median', linestyle='dashed')
plt.title('SAT Score', fontsize=18)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc = 'upper right', frameon=False, fontsize = 16);
plt.grid(False)

# show plot
plt.show()

# %% [markdown]
# **Trends:**
#
# ACT: both average and median scores dropped
#
# SAT: average scores dropped but median scores increased

# %% [markdown]
# ##### 3.3 SAT Scores - Breakdown in Math and ERBW

# %%
# using subplot function and creating plot one
fig, ax = plt.subplots(figsize=(15, 5))

plt.subplot(1, 2, 1)  # row 1, column 2, count 1
plt.plot(score_summary['Year'],score_summary['SAT_avg_math_score'], color = 'mediumvioletred', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['SAT_median_math_score'], color = 'mediumvioletred', marker = 'o', linewidth=4, linestyle='dashed', label = 'Median')
plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


plt.title('SAT Score (Math)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Score', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(ymin=530)
plt.ylim(ymax=570)
plt.grid(False)

# using subplot function and creating plot two
# row 1, column 2, count 2
plt.subplot(1, 2, 2)
 
plt.plot(score_summary['Year'],score_summary['SAT_avg_ebrw_score'], color = 'orchid', marker = 'o', linewidth=4, label = 'Avg')
plt.plot(score_summary['Year'],score_summary['SAT_median_ebrw_score'], color = 'orchid', marker = 'o', linewidth=4, linestyle='dashed', label = 'Median')
plt.title('SAT Score (EBRW)', fontsize=18)
plt.xlabel('Year', fontsize=16)
plt.ylabel('Score', fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid(False)
plt.ylim(ymin=530)
plt.ylim(ymax=570)

plt.legend(loc = 'upper right', frameon=False, fontsize = 16);


# show plot
plt.show()

# %% [markdown]
# **Trends:**
#
# Comparing Math and EBRW scores, students still do better in EBRW.
#
# However, scores for Math is trending upwards for median, but scores for EBRW is trending downwards (both median and average).
#
# We should also explore the entire distribution, instead of just average and median.

# %%
math = merged.loc[:,['state','sat_math_avg_score_2017','sat_math_avg_score_2018', 'sat_math_avg_score_2019']]
ebrw = merged.loc[:,['state','sat_ebrw_avg_score_2017','sat_ebrw_avg_score_2018', 'sat_ebrw_avg_score_2019']]


boxprops = dict(linewidth=5, color='mediumvioletred')
medianprops = dict(linewidth=5, color='mediumvioletred')

boxprops2 = dict(linewidth=5, color='orchid')
medianprops2 = dict(linewidth=5, color='orchid')

#create figure
fig = plt.figure()

#set subplots
ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)


#ax0
math.plot(kind='box',figsize=(25,10), color = 'mediumvioletred', ax = ax0, fontsize=16, boxprops=boxprops, medianprops=medianprops, showfliers=False)
ax0.set_title('Math (2017 to 2019)', fontsize = 25)
ax0.set_ylabel('Avg Scores', fontsize = 20)
ax0.set_xlabel('SAT - Math', fontsize = 20)
ax0.grid(False)


ebrw.plot(kind='box',figsize=(25, 10), color = 'orchid', ax = ax1,fontsize=16, boxprops=boxprops2, medianprops=medianprops2,showfliers=False)
ax1.set_title('EBRW (2017 to 2019)', fontsize = 25)
ax1.set_ylabel('Avg Scores', fontsize = 20)
ax1.set_xlabel('SAT - EBRW', fontsize = 20)
ax1.grid(False)

# %% [markdown]
# **Trends:**
#
# Math scores gets more widely distributed. But it is trending upwards.
#
# EBRW scores gets more widely distributed. But it is trending downwards.

# %%
all2017 = merged.loc[:,['state','sat_math_avg_score_2017', 'sat_ebrw_avg_score_2017']]
all2018 = merged.loc[:,['state','sat_math_avg_score_2018','sat_ebrw_avg_score_2018']]
all2019 = merged.loc[:,['state','sat_math_avg_score_2019','sat_ebrw_avg_score_2019']]


boxprops = dict(linewidth=5, color='purple')
medianprops = dict(linewidth=5, color='purple')


#create figure
fig = plt.figure()

#set subplots
ax0 = fig.add_subplot(1,3,1)
ax1 = fig.add_subplot(1,3,2)
ax2 = fig.add_subplot(1,3,3)


#ax0
all2017.plot(kind='box',figsize=(25,10), color = 'purple', ax = ax0, fontsize=16, boxprops=boxprops, medianprops=medianprops, showfliers=False)
ax0.set_title('2017 SAT Avg Scores (Math vs EBRW)', fontsize = 25)
ax0.set_ylabel('Avg Scores', fontsize = 20)
ax0.set_xlabel('SAT', fontsize = 20)
ax0.grid(False)


all2018.plot(kind='box',figsize=(25, 10), color = 'purple', ax = ax1,fontsize=16, boxprops=boxprops, medianprops=medianprops,showfliers=False)
ax1.set_title('2018 SAT Avg Scores (Math vs EBRW)', fontsize = 25)
ax1.set_ylabel('Avg Scores', fontsize = 20)
ax1.set_xlabel('SAT', fontsize = 20)
ax1.grid(False)

all2019.plot(kind='box',figsize=(25,10), color = 'purple', ax = ax2,fontsize=16, boxprops=boxprops, medianprops=medianprops,showfliers=False)
ax2.set_title('2019 SAT Avg Scores (Math vs EBRW)', fontsize = 25)
ax2.set_ylabel('Avg Scores', fontsize = 20)
ax2.set_xlabel('SAT', fontsize = 20)
ax2.grid(False)

# %% [markdown]
# **Trends:**
#
# EBRW scores used to be much higher compared to Math Scores. But over the years, the gap is getting smaller.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Problem Statement:**
#
# Was this decision beneficial for College Board in its competition against ACT Inc. in its fight for market share?
#
#      - Did this decision cause any change in SAT participation rate?
#
#      - Did this decision encourage students strong in Mathematics to sit for SAT?
#
#      - Did these students switch over to SAT and abandon ACT? Or did they take both tests?
#
#
# **Key Takeaways:**
#
# The new SAT format has attracted more students and has increased the participation rate.
# On the other hand, participation rate for ACT has dropped.
# However, we do see a greater proportion of students who take both SAT and ACT.
#
# Although the average score of SAT has dropped, the median score of SAT has increased slightly.
#
# Looking at the details of the score, on the whole, scores for Math has improved.
# This could signal that more mathematically strong students are attracted by the change in format, and have decided to try SAT (instead of ACT).
#
# States who used to participate mainly in ACT, is now taking up SAT. Students are choosing to take up SAT (on top of ACT) to have a chance in both.
